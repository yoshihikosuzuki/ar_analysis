# %%
PR=data/pressrelease_all.csv

# %%
wc -l ${PR}
# Out:
#   336465 data/pressrelease_all.csv

# %%
grep "都\|道\|府\|県" ${PR} | wc -l
# Out:
#   212727

# %%
grep "市\|区\|町\|村" ${PR} | wc -l
# Out:
#   256526

# %% [markdown]
# 市区町村はさすがにひどいか。道とかも。

# %%
grep "本社" ${PR} | wc -l
# Out:
#   171576

# %%
grep "東京都" ${PR} | grep -v "本社" | head -10
# Out:
# NIKPRLRSP038296_10012003	20030109	発表日：２００３年１月１０日「のぞみ朝割きっぷ」平成１５年２月～３月分の発売について　ＪＲ東海とＪＲ西日本では、岡山・広島から首都圏に新幹線をご利用して往復されるお客様を対象に、「ゆき」は指定された早朝の「のぞみ」の普通車指定席をご利用いただき、「かえり」はお客様が希望される「のぞみ」の普通車指定席をご利用いただける、大変おトクな「のぞみ朝割（あさわり）きっぷ」を発売しておりますが、お客様のご利用状況を踏まえて、以下のとおり平成１５年２月から３月分の発売をいたします。　岡山・広島から首都圏への日帰りの出張にぜひご利用ください。【この商品のここがポイント】・「ゆき」は岡山発「のぞみ２号」または「のぞみ４号」、広島発「のぞみ４号」の普通車指定席がご利用いただけます。・「かえり」はお客様が希望される「のぞみ」の普通車指定席がご利用いただけます。　もちろん「ひかり」「こだま」の普通車指定席もご利用いただけます。　※「かえり」の列車は、乗車列車の変更が１回できます。・おねだんは、　岡山～東京都区内または横浜市内２５，０００円（往復）　　※例えば、岡山～東京都区内の場合、通常より８，３４０円もおトク　広島市内～東京都区内または横浜市内３０，０００円（往復）　　※例えば、広島市内～東京都区内の場合、通常より７，０８０円もおトク・ご利用期間は平成１５年２月１日から平成１５年３月３１日までです。　※平成１５年４月以降の発売については、別途お知らせします。・発売はご乗車日の３週間前から前日まで行います。・ご予約いただける席数はご利用日毎に限りがございます。お早めにお求めください。※詳細は別紙　商品概要をご覧下さい。（※　関連資料参照）
# ...

# %% [markdown]
# "本社"の文字無しで本社の住所を記載していることもある。
#
# "本社"をつけて最後の方にまとめて記載していることもある。
#
# -> "本社"の近くから探してくるのがいい？それとも最初から完全マッチングで検索？それとも本文から見つけてくるようにする？
